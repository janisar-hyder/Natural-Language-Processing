# %%
from google.colab import drive
drive.mount('/content/drive')

short_pos = open("/content/drive/My Drive/Colab Notebooks/pos.txt","r").read()
short_neg = open("/content/drive/My Drive/Colab Notebooks/neg.txt","r").read()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
documents = []

for r in short_pos.split('\n'):
    documents.append( (r, "pos") )

for r in short_neg.split('\n'):
    documents.append( (r, "neg") )


documents[:5]
len(documents)
# Out:
# [('the rock is destined to be the 21st century\'s new " conan " and that he\'s going to make a splash even greater than arnold schwarzenegger , jean-claud van damme or steven segal . ',
#   'pos'),
#  ('the gorgeously elaborate continuation of " the lord of the rings " trilogy is so huge that a column of words cannot adequately describe co-writer/director peter jackson\'s expanded vision of j . r . r . tolkien\'s middle-earth . ',
#   'pos'),
#  ('effective but too-tepid biopic', 'pos'),
#  ('if you sometimes like to go to the movies to have fun , wasabi is a good place to start . ',
#   'pos'),
#  ("emerges as something rare , an issue movie that's so honest and keenly observed that it doesn't feel like one . ",
#   'pos')]

# %%
import nltk
nltk.download('punkt')

from nltk.tokenize import word_tokenize

all_words = []

short_pos_words = word_tokenize(short_pos)
short_neg_words = word_tokenize(short_neg)

for w in short_pos_words:
    all_words.append(w.lower())

for w in short_neg_words:
    all_words.append(w.lower())

all_words = nltk.FreqDist(all_words)

len(all_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 20317

# %%
word_features = list(all_words.keys())[:5000]
word_features
# Out:
# ['the',
#  'rock',
#  'is',
#  'destined',
#  'to',
#  'be',
#  '21st',
#  'century',
#  "'s",
#  'new',
#  '``',
#  'conan',
#  'and',
#  'that',
#  'he',
#  'going',
#  'make',
#  'a',
#  'splash',
#  'even',
#  'greater',
#  'than',
#  'arnold',
#  'schwarzenegger',
#  ',',
#  'jean-claud',
#  'van',
#  'damme',
#  'or',
#  'steven',
#  'segal',
#  '.',
#  'gorgeously',
#  'elaborate',
#  'continuation',
#  'of',
#  'lord',
#  'rings',
#  'trilogy',
#  'so',
#  'huge',
#  'column',
#  'words',
#  'can',
#  'not',
#  'adequately',
#  'describe',
#  'co-writer/director',
#  'peter',
#  'jackson',
#  'expanded',
#  'vision',
#  'j',
#  'r',
#  'tolkien',
#  'middle-earth',
#  'effective',
#  'but',
#  'too-tepid',
#  'biopic',
#  'if',
#  'you',
#  'sometimes',
#  'like',
#  'go',
#  'movies',
#  'have',
#  'fun',
#  'wasabi',
#  'good',
#  'place',
#  'start',
#  'emerges',
#  'as',
#  'something',
#  'rare',
#  'an',
#  'issue',
#  'movie',
#  'honest',
#  'keenly',
#  'observed',
#  'it',
#  'does',
#  "n't",
#  'feel',
#  'one',
#  'film',
#  'provides',
#  'some',
#  'great',
#  'insight',
#  'into',
#  'neurotic',
#  'mindset',
#  'all',
#  'comics',
#  '--',
#  'those',
#  'who',
#  'reached',
#  'absolute',
#  'top',
#  'game',
#  'offers',
#  'combination',
#  'entertainment',
#  'education',
#  'perhaps',
#  'no',
#  'picture',
#  'ever',
#  'made',
#  'has',
#  'more',
#  'literally',
#  'showed',
#  'road',
#  'hell',
#  'paved',
#  'with',
#  'intentions',
#  'steers',
#  'turns',
#  'in',
#  'snappy',
#  'screenplay',
#  'curls',
#  'at',
#  'edges',
#  ';',
#  'clever',
#  'want',
#  'hate',
#  'somehow',
#  'pulls',
#  'off',
#  'take',
#  'care',
#  'my',
#  'cat',
#  'refreshingly',
#  'different',
#  'slice',
#  'asian',
#  'cinema',
#  'this',
#  'well',
#  'worth',
#  'seeing',
#  'talking',
#  'singing',
#  'heads',
#  'what',
#  'really',
#  'surprises',
#  'about',
#  'wisegirls',
#  'its',
#  'low-key',
#  'quality',
#  'genuine',
#  'tenderness',
#  '(',
#  'wendigo',
#  ')',
#  'why',
#  'we',
#  ':',
#  'fed',
#  'through',
#  'eye',
#  'heart',
#  'mind',
#  'greatest',
#  'family-oriented',
#  'fantasy-adventure',
#  'ultimately',
#  'ponders',
#  'reasons',
#  'need',
#  'stories',
#  'much',
#  'utterly',
#  'compelling',
#  "'who",
#  'wrote',
#  "'",
#  'which',
#  'reputation',
#  'most',
#  'famous',
#  'author',
#  'lived',
#  'comes',
#  'question',
#  'illuminating',
#  'overly',
#  'talky',
#  'documentary',
#  'masterpiece',
#  'four',
#  'years',
#  'making',
#  'ripe',
#  'enrapturing',
#  'beauty',
#  'will',
#  'tempt',
#  'willing',
#  'probe',
#  'inscrutable',
#  'mysteries',
#  'breath',
#  'fresh',
#  'air',
#  'true',
#  'sophistication',
#  'thoughtful',
#  'provocative',
#  'insistently',
#  'humanizing',
#  'cast',
#  'includes',
#  'actors',
#  'working',
#  'independent',
#  'lovely',
#  '&',
#  'amazing',
#  'involves',
#  'us',
#  'because',
#  'incisive',
#  'bleakly',
#  'amusing',
#  'how',
#  'our',
#  'lives',
#  'disturbing',
#  'frighteningly',
#  'evocative',
#  'assembly',
#  'imagery',
#  'hypnotic',
#  'music',
#  'composed',
#  'by',
#  'philip',
#  'glass',
#  'for',
#  'everyone',
#  'whom',
#  'connect',
#  'nice',
#  'departure',
#  'from',
#  'standard',
#  'moviegoing',
#  'fare',
#  'scores',
#  'few',
#  'points',
#  'doing',
#  'dedicated',
#  'good-hearted',
#  'professionalism',
#  'occasionally',
#  'melodramatic',
#  'also',
#  'extremely',
#  'spiderman',
#  'rocks',
#  'idealistic',
#  'love',
#  'story',
#  'brings',
#  'out',
#  'latent',
#  '15-year-old',
#  'romantic',
#  '95',
#  'minutes',
#  'treasure',
#  'planet',
#  'maintains',
#  'brisk',
#  'pace',
#  'races',
#  'familiar',
#  'however',
#  'lacks',
#  'grandeur',
#  'epic',
#  'often',
#  'associated',
#  'stevenson',
#  'tale',
#  'earlier',
#  'disney',
#  'efforts',
#  'helps',
#  'lil',
#  'bow',
#  'wow',
#  'tones',
#  'down',
#  'his',
#  'pint-sized',
#  'gangsta',
#  'act',
#  'play',
#  'someone',
#  'resembles',
#  'real',
#  'kid',
#  'guaranteed',
#  'move',
#  'anyone',
#  'shook',
#  'rattled',
#  'rolled',
#  'masterful',
#  'master',
#  'filmmaker',
#  'unique',
#  'deceptive',
#  'grimness',
#  'fatalist',
#  'worldview',
#  'light',
#  'cute',
#  'forgettable',
#  'there',
#  'way',
#  'effectively',
#  'teach',
#  'kids',
#  'dangers',
#  'drugs',
#  'i',
#  'think',
#  'projects',
#  'unfortunately',
#  'r-rated',
#  'paid',
#  'while',
#  'would',
#  'easy',
#  'give',
#  'crush',
#  'title',
#  'two',
#  'weddings',
#  'funeral',
#  'far',
#  'any',
#  'hugh',
#  'grant',
#  'whimsy',
#  'though',
#  'everything',
#  'might',
#  'literate',
#  'smart',
#  'never',
#  'took',
#  'always',
#  'seemed',
#  'static',
#  'cantet',
#  'perfectly',
#  'captures',
#  'hotel',
#  'lobbies',
#  'two-lane',
#  'highways',
#  'roadside',
#  'cafes',
#  'permeate',
#  'vincent',
#  'days',
#  'ms',
#  'fulford-wierzbicki',
#  'almost',
#  'spooky',
#  'her',
#  'sulky',
#  'calculating',
#  'lolita',
#  'turn',
#  'means',
#  'best',
#  'work',
#  'laissez-passer',
#  'distinguished',
#  'distinctive',
#  'effort',
#  'bona-fide',
#  'fascinating',
#  'replete',
#  'rewards',
#  'had',
#  'reap',
#  'them',
#  'bond',
#  'outings',
#  'recent',
#  'stunts',
#  'are',
#  'outlandish',
#  'they',
#  'border',
#  'on',
#  'being',
#  'cartoonlike',
#  'heavy',
#  'reliance',
#  'cgi',
#  'technology',
#  'beginning',
#  'creep',
#  'series',
#  'newton',
#  'draws',
#  'attention',
#  'magnet',
#  'acts',
#  'circles',
#  'around',
#  'better',
#  'known',
#  'co-star',
#  'mark',
#  'wahlberg',
#  'loses',
#  'bite',
#  'last-minute',
#  'happy',
#  'ending',
#  'less',
#  'plausible',
#  'rest',
#  'novel',
#  'ride',
#  'fuller',
#  'surely',
#  'called',
#  'gutsy',
#  'times',
#  'exhilarating',
#  'yarn',
#  "'compleja",
#  'e',
#  'intelectualmente',
#  'retadora',
#  'el',
#  'ladrón',
#  'de',
#  'orquídeas',
#  'es',
#  'uno',
#  'esos',
#  'filmes',
#  'que',
#  'vale',
#  'la',
#  'pena',
#  'ver',
#  'precisamente',
#  'por',
#  'su',
#  'originalidad',
#  'makes',
#  'strong',
#  'case',
#  'importance',
#  'musicians',
#  'creating',
#  'motown',
#  'sound',
#  'karmen',
#  'moves',
#  'rhythm',
#  'itself',
#  'lips',
#  'chanting',
#  'beat',
#  'long',
#  'braided',
#  'hair',
#  'little',
#  'wipe',
#  'away',
#  'jeweled',
#  'beads',
#  'sweat',
#  'gosling',
#  'performance',
#  'dwarfs',
#  'else',
#  'people',
#  'gives',
#  'glimpse',
#  'culture',
#  'do',
#  'know',
#  'tender',
#  'yet',
#  'lacerating',
#  'darkly',
#  'funny',
#  'fable',
#  'may',
#  'spoofing',
#  'target',
#  'old',
#  "'50",
#  'giant',
#  'creature',
#  'features',
#  'acknowledges',
#  'celebrates',
#  'their',
#  'cheesiness',
#  'reason',
#  'get',
#  'kick',
#  'watching',
#  'today',
#  'engaging',
#  'overview',
#  'johnson',
#  'eccentric',
#  'career',
#  'ragged',
#  'cheap',
#  'unassuming',
#  'works',
#  'charisma',
#  "'d",
#  'listen',
#  'reading',
#  'phone',
#  'book',
#  'sandra',
#  'bullock',
#  'such',
#  'likeable',
#  'nettelbeck',
#  'beautifully',
#  'orchestrates',
#  'transformation',
#  'chilly',
#  'self-absorbed',
#  'martha',
#  'begins',
#  'open',
#  'behind',
#  'snow',
#  'games',
#  'lovable',
#  'siberian',
#  'huskies',
#  'plus',
#  'sheep',
#  'dog',
#  'hosts',
#  'parka-wrapped',
#  'dose',
#  'everytime',
#  'undercover',
#  'brother',
#  'run',
#  'steam',
#  'finds',
#  'surprise',
#  'amuse',
#  'manages',
#  'original',
#  'rips',
#  'many',
#  'ideas',
#  'singer/composer',
#  'bryan',
#  'adams',
#  'contributes',
#  'slew',
#  'songs',
#  '—',
#  'potential',
#  'hits',
#  'simply',
#  'intrusive',
#  'whole',
#  'package',
#  'certainly',
#  'intended',
#  'er',
#  'spirit',
#  'piece',
#  'now',
#  'america',
#  'enough',
#  'plucky',
#  'british',
#  'eccentrics',
#  'hearts',
#  'gold',
#  'still',
#  'charming',
#  'here',
#  'whether',
#  "'re",
#  'enlightened',
#  'derrida',
#  'lectures',
#  'other',
#  'self',
#  'undeniably',
#  'playful',
#  'fellow',
#  'pleasant',
#  'held',
#  'together',
#  'skilled',
#  'ensemble',
#  'american',
#  'troubled',
#  'teens',
#  'since',
#  '1998',
#  'whatever',
#  'been',
#  'hit-or-miss',
#  'when',
#  'bringing',
#  'beloved',
#  'books',
#  'screen',
#  'tuck',
#  'everlasting',
#  'both',
#  'just',
#  'labour',
#  'involved',
#  'layered',
#  'richness',
#  'chiaroscuro',
#  'madness',
#  'astonishing',
#  'animated',
#  'subplot',
#  'depicts',
#  'inner',
#  'struggles',
#  'adolescent',
#  'heroes',
#  '-',
#  'insecure',
#  'uncontrolled',
#  'intense',
#  'invincible',
#  'werner',
#  'herzog',
#  'alive',
#  'living',
#  'morton',
#  'actress',
#  'portraying',
#  'complex',
#  'character',
#  'morvern',
#  'callar',
#  'grows',
#  'farther',
#  'meanders',
#  'shocking',
#  'part',
#  'charm',
#  'satin',
#  'rouge',
#  'avoids',
#  'obvious',
#  'humour',
#  'lightness',
#  'son',
#  'bride',
#  'half-hour',
#  'too',
#  'flattering',
#  'sense',
#  'mystery',
#  'quietness',
#  'simmering',
#  'psychological',
#  'drama',
#  'bursts',
#  'sudden',
#  'violence',
#  'startling',
#  'slow',
#  'buildup',
#  'preceded',
#  'taut',
#  'intelligent',
#  'coming-of-age',
#  'arduous',
#  'journey',
#  'sensitive',
#  'young',
#  'girl',
#  'foster',
#  'homes',
#  'fierce',
#  'struggle',
#  'pull',
#  'free',
#  'dangerous',
#  'domineering',
#  'mother',
#  'hold',
#  'over',
#  'truly',
#  'moving',
#  'experience',
#  'perfect',
#  'example',
#  'art',
#  'done',
#  'right',
#  'help',
#  'heal',
#  'clarify',
#  'comfort',
#  'delicately',
#  'deeply',
#  'felt',
#  'masterfully',
#  'stylized',
#  'triumph',
#  'maverick',
#  'director',
#  'deftly',
#  'wrought',
#  'suspense',
#  'whose',
#  'richer',
#  'shadings',
#  'coloring',
#  'rather',
#  'substance',
#  'appearance',
#  'treebeard',
#  'gollum',
#  'role',
#  'either',
#  'loving',
#  'rolling',
#  'your',
#  'eyes',
#  'loved',
#  '!',
#  "'performance",
#  'incredible',
#  'ingeniously',
#  'constructed',
#  'memento',
#  'were',
#  'page-turner',
#  'ca',
#  'wait',
#  'see',
#  'happens',
#  'next',
#  'haneke',
#  'challenges',
#  'confront',
#  'reality',
#  'sexual',
#  'aberration',
#  'absorbing',
#  'originally',
#  'clarity',
#  'gone',
#  'year',
#  'benchmark',
#  'against',
#  'contenders',
#  'should',
#  'measured',
#  'painful',
#  'watch',
#  'viewers',
#  'chance',
#  'rewarded',
#  'accomplished',
#  'riveting',
#  'performances',
#  'albeit',
#  'depressing',
#  'view',
#  'iranian',
#  'rural',
#  'life',
#  'close',
#  'iraqi',
#  'imaginative',
#  'comedy/thriller',
#  'artsy',
#  'flourishes',
#  'aside',
#  'narc',
#  'gritty',
#  'gets',
#  'these',
#  'isle',
#  'preposterous',
#  'thoroughly',
#  'misogynistic',
#  'vistas',
#  'incredibly',
#  'beautiful',
#  'look',
#  'tok',
#  'o',
#  'orchestrate',
#  'buoyant',
#  'dance',
#  'death',
#  'process',
#  'demonstrate',
#  'lot',
#  'hong',
#  'kong',
#  'kapur',
#  'flair',
#  'landscapes',
#  'adventure',
#  'english-language',
#  'overpraised',
#  'elizabeth',
#  'blast',
#  'educational',
#  'energy',
#  'bouncy',
#  'animation',
#  'catchy',
#  'escort',
#  'entire',
#  '85',
#  'sports',
#  'action',
#  'exciting',
#  'field',
#  'doug',
#  'liman',
#  'bourne',
#  'directs',
#  'traffic',
#  'wintry',
#  'locations',
#  'absorbs',
#  'spycraft',
#  'uses',
#  'damon',
#  'ability',
#  'focused',
#  'sincere',
#  'intact',
#  'katz',
#  'archival',
#  'footage',
#  'horrifying',
#  'documents',
#  'lynchings',
#  'photographs',
#  'reel-to-reel',
#  'recordings',
#  'meeropol',
#  'entertaining',
#  'children',
#  'create',
#  'song',
#  'history',
#  'powerful',
#  'anthropologically',
#  'detailed',
#  'realization',
#  "early-'80s",
#  'suburbia',
#  'significant',
#  'without',
#  'overstated',
#  'mcfarlane',
#  'lifts',
#  'firmly',
#  'above',
#  'level',
#  'films',
#  'jarring',
#  'hard',
#  'back',
#  'boys',
#  'nothing',
#  'introduces',
#  'promising',
#  'unusual',
#  'kind',
#  'horror',
#  'normal',
#  'bromides',
#  'barely',
#  'sustain',
#  'interstitial',
#  'program',
#  'discovery',
#  'channel',
#  'imax',
#  '3-d',
#  'clichés',
#  'disappear',
#  'vertiginous',
#  'perspectives',
#  'opened',
#  'up',
#  'photography',
#  'writer-director',
#  'burger',
#  'imaginatively',
#  'fans',
#  'embers',
#  'dormant',
#  'national',
#  'grief',
#  'curiosity',
#  'calcified',
#  'chronic',
#  'cynicism',
#  'fear',
#  'roller-coaster',
#  'enjoyed',
#  'time',
#  'favor',
#  'was',
#  'surprised',
#  'quickly',
#  'faded',
#  'memory',
#  'chicago',
#  'sophisticated',
#  'brash',
#  'sardonic',
#  'completely',
#  'joyful',
#  'execution',
#  'steve',
#  'irwin',
#  'method',
#  'ernest',
#  'hemmingway',
#  'accelerated',
#  'speed',
#  'volume',
#  'refreshing',
#  'korean',
#  'five',
#  'female',
#  'high',
#  'school',
#  'friends',
#  'face',
#  'uphill',
#  'battle',
#  'try',
#  'relationships',
#  'deeper',
#  'waters',
#  'surface',
#  'lovers-on-the-run',
#  'crime',
#  'flick',
#  'common',
#  'piesiewicz',
#  'kieslowski',
#  'double',
#  'veronique',
#  'values',
#  'enterprise',
#  'crew',
#  'previous',
#  'adventures',
#  'perils',
#  'again-courage',
#  'self-sacrifice',
#  'patience',
#  'under',
#  'pressure',
#  'possible',
#  'sequel',
#  ...]

# %%
def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

# %%
featuresets = [(find_features(rev), category) for (rev, category) in documents]

# %%
import random

random.shuffle(featuresets)

featuresets[0]
# Out:
# ({'the': True,
#   'rock': False,
#   'is': True,
#   'destined': False,
#   'to': False,
#   'be': False,
#   '21st': False,
#   'century': False,
#   "'s": False,
#   'new': False,
#   '``': False,
#   'conan': False,
#   'and': False,
#   'that': True,
#   'he': False,
#   'going': False,
#   'make': False,
#   'a': False,
#   'splash': False,
#   'even': False,
#   'greater': False,
#   'than': False,
#   'arnold': False,
#   'schwarzenegger': False,
#   ',': False,
#   'jean-claud': False,
#   'van': False,
#   'damme': False,
#   'or': False,
#   'steven': False,
#   'segal': False,
#   '.': True,
#   'gorgeously': False,
#   'elaborate': False,
#   'continuation': False,
#   'of': False,
#   'lord': False,
#   'rings': False,
#   'trilogy': False,
#   'so': False,
#   'huge': False,
#   'column': False,
#   'words': False,
#   'can': False,
#   'not': False,
#   'adequately': False,
#   'describe': False,
#   'co-writer/director': False,
#   'peter': False,
#   'jackson': False,
#   'expanded': False,
#   'vision': False,
#   'j': False,
#   'r': False,
#   'tolkien': False,
#   'middle-earth': False,
#   'effective': False,
#   'but': False,
#   'too-tepid': False,
#   'biopic': False,
#   'if': False,
#   'you': False,
#   'sometimes': False,
#   'like': False,
#   'go': False,
#   'movies': False,
#   'have': False,
#   'fun': False,
#   'wasabi': False,
#   'good': False,
#   'place': False,
#   'start': False,
#   'emerges': False,
#   'as': False,
#   'something': False,
#   'rare': False,
#   'an': False,
#   'issue': False,
#   'movie': False,
#   'honest': False,
#   'keenly': False,
#   'observed': False,
#   'it': True,
#   'does': False,
#   "n't": False,
#   'feel': False,
#   'one': False,
#   'film': True,
#   'provides': False,
#   'some': False,
#   'great': False,
#   'insight': False,
#   'into': True,
#   'neurotic': False,
#   'mindset': False,
#   'all': False,
#   'comics': False,
#   '--': False,
#   'those': False,
#   'who': False,
#   'reached': False,
#   'absolute': False,
#   'top': False,
#   'game': False,
#   'offers': False,
#   'combination': False,
#   'entertainment': False,
#   'education': False,
#   'perhaps': False,
#   'no': False,
#   'picture': False,
#   'ever': False,
#   'made': False,
#   'has': False,
#   'more': False,
#   'literally': False,
#   'showed': False,
#   'road': False,
#   'hell': False,
#   'paved': False,
#   'with': False,
#   'intentions': False,
#   'steers': False,
#   'turns': False,
#   'in': False,
#   'snappy': False,
#   'screenplay': False,
#   'curls': False,
#   'at': False,
#   'edges': False,
#   ';': False,
#   'clever': False,
#   'want': False,
#   'hate': False,
#   'somehow': False,
#   'pulls': False,
#   'off': False,
#   'take': False,
#   'care': False,
#   'my': False,
#   'cat': False,
#   'refreshingly': False,
#   'different': False,
#   'slice': False,
#   'asian': False,
#   'cinema': False,
#   'this': True,
#   'well': False,
#   'worth': False,
#   'seeing': False,
#   'talking': False,
#   'singing': False,
#   'heads': False,
#   'what': False,
#   'really': False,
#   'surprises': False,
#   'about': True,
#   'wisegirls': False,
#   'its': False,
#   'low-key': False,
#   'quality': False,
#   'genuine': False,
#   'tenderness': False,
#   '(': False,
#   'wendigo': False,
#   ')': False,
#   'why': False,
#   'we': False,
#   ':': False,
#   'fed': False,
#   'through': False,
#   'eye': False,
#   'heart': False,
#   'mind': False,
#   'greatest': False,
#   'family-oriented': False,
#   'fantasy-adventure': False,
#   'ultimately': False,
#   'ponders': False,
#   'reasons': False,
#   'need': False,
#   'stories': False,
#   'much': False,
#   'utterly': False,
#   'compelling': False,
#   "'who": False,
#   'wrote': False,
#   "'": False,
#   'which': False,
#   'reputation': False,
#   'most': True,
#   'famous': False,
#   'author': False,
#   'lived': False,
#   'comes': False,
#   'question': False,
#   'illuminating': False,
#   'overly': False,
#   'talky': False,
#   'documentary': False,
#   'masterpiece': False,
#   'four': False,
#   'years': False,
#   'making': False,
#   'ripe': False,
#   'enrapturing': False,
#   'beauty': False,
#   'will': False,
#   'tempt': False,
#   'willing': False,
#   'probe': False,
#   'inscrutable': False,
#   'mysteries': False,
#   'breath': False,
#   'fresh': False,
#   'air': False,
#   'true': False,
#   'sophistication': False,
#   'thoughtful': False,
#   'provocative': False,
#   'insistently': False,
#   'humanizing': False,
#   'cast': False,
#   'includes': False,
#   'actors': False,
#   'working': False,
#   'independent': False,
#   'lovely': False,
#   '&': False,
#   'amazing': False,
#   'involves': False,
#   'us': False,
#   'because': False,
#   'incisive': False,
#   'bleakly': False,
#   'amusing': False,
#   'how': False,
#   'our': False,
#   'lives': False,
#   'disturbing': False,
#   'frighteningly': False,
#   'evocative': False,
#   'assembly': False,
#   'imagery': False,
#   'hypnotic': False,
#   'music': False,
#   'composed': False,
#   'by': False,
#   'philip': False,
#   'glass': False,
#   'for': False,
#   'everyone': False,
#   'whom': False,
#   'connect': False,
#   'nice': False,
#   'departure': False,
#   'from': False,
#   'standard': False,
#   'moviegoing': False,
#   'fare': False,
#   'scores': False,
#   'few': False,
#   'points': False,
#   'doing': False,
#   'dedicated': False,
#   'good-hearted': False,
#   'professionalism': False,
#   'occasionally': False,
#   'melodramatic': False,
#   'also': False,
#   'extremely': False,
#   'spiderman': False,
#   'rocks': False,
#   'idealistic': False,
#   'love': False,
#   'story': False,
#   'brings': False,
#   'out': False,
#   'latent': False,
#   '15-year-old': False,
#   'romantic': False,
#   '95': False,
#   'minutes': False,
#   'treasure': False,
#   'planet': False,
#   'maintains': False,
#   'brisk': False,
#   'pace': False,
#   'races': False,
#   'familiar': False,
#   'however': False,
#   'lacks': False,
#   'grandeur': False,
#   'epic': False,
#   'often': False,
#   'associated': False,
#   'stevenson': False,
#   'tale': False,
#   'earlier': False,
#   'disney': False,
#   'efforts': False,
#   'helps': False,
#   'lil': False,
#   'bow': False,
#   'wow': False,
#   'tones': False,
#   'down': False,
#   'his': False,
#   'pint-sized': False,
#   'gangsta': False,
#   'act': False,
#   'play': False,
#   'someone': False,
#   'resembles': False,
#   'real': False,
#   'kid': False,
#   'guaranteed': False,
#   'move': False,
#   'anyone': False,
#   'shook': False,
#   'rattled': False,
#   'rolled': False,
#   'masterful': False,
#   'master': False,
#   'filmmaker': False,
#   'unique': False,
#   'deceptive': False,
#   'grimness': False,
#   'fatalist': False,
#   'worldview': False,
#   'light': False,
#   'cute': False,
#   'forgettable': False,
#   'there': False,
#   'way': False,
#   'effectively': False,
#   'teach': False,
#   'kids': False,
#   'dangers': False,
#   'drugs': False,
#   'i': False,
#   'think': False,
#   'projects': False,
#   'unfortunately': False,
#   'r-rated': False,
#   'paid': False,
#   'while': False,
#   'would': False,
#   'easy': False,
#   'give': False,
#   'crush': False,
#   'title': False,
#   'two': False,
#   'weddings': False,
#   'funeral': False,
#   'far': False,
#   'any': False,
#   'hugh': False,
#   'grant': False,
#   'whimsy': False,
#   'though': False,
#   'everything': False,
#   'might': False,
#   'literate': False,
#   'smart': False,
#   'never': False,
#   'took': False,
#   'always': False,
#   'seemed': False,
#   'static': False,
#   'cantet': False,
#   'perfectly': False,
#   'captures': False,
#   'hotel': False,
#   'lobbies': False,
#   'two-lane': False,
#   'highways': False,
#   'roadside': False,
#   'cafes': False,
#   'permeate': False,
#   'vincent': False,
#   'days': False,
#   'ms': False,
#   'fulford-wierzbicki': False,
#   'almost': False,
#   'spooky': False,
#   'her': False,
#   'sulky': False,
#   'calculating': False,
#   'lolita': False,
#   'turn': False,
#   'means': False,
#   'best': False,
#   'work': False,
#   'laissez-passer': False,
#   'distinguished': False,
#   'distinctive': False,
#   'effort': False,
#   'bona-fide': False,
#   'fascinating': False,
#   'replete': False,
#   'rewards': False,
#   'had': False,
#   'reap': False,
#   'them': False,
#   'bond': False,
#   'outings': False,
#   'recent': False,
#   'stunts': False,
#   'are': True,
#   'outlandish': False,
#   'they': True,
#   'border': False,
#   'on': False,
#   'being': False,
#   'cartoonlike': False,
#   'heavy': False,
#   'reliance': False,
#   'cgi': False,
#   'technology': False,
#   'beginning': False,
#   'creep': False,
#   'series': False,
#   'newton': False,
#   'draws': False,
#   'attention': False,
#   'magnet': False,
#   'acts': False,
#   'circles': False,
#   'around': False,
#   'better': False,
#   'known': False,
#   'co-star': False,
#   'mark': False,
#   'wahlberg': False,
#   'loses': False,
#   'bite': False,
#   'last-minute': False,
#   'happy': False,
#   'ending': False,
#   'less': False,
#   'plausible': False,
#   'rest': False,
#   'novel': False,
#   'ride': False,
#   'fuller': False,
#   'surely': False,
#   'called': False,
#   'gutsy': False,
#   'times': False,
#   'exhilarating': False,
#   'yarn': False,
#   "'compleja": False,
#   'e': False,
#   'intelectualmente': False,
#   'retadora': False,
#   'el': False,
#   'ladrón': False,
#   'de': False,
#   'orquídeas': False,
#   'es': False,
#   'uno': False,
#   'esos': False,
#   'filmes': False,
#   'que': False,
#   'vale': False,
#   'la': False,
#   'pena': False,
#   'ver': False,
#   'precisamente': False,
#   'por': False,
#   'su': False,
#   'originalidad': False,
#   'makes': False,
#   'strong': False,
#   'case': False,
#   'importance': False,
#   'musicians': False,
#   'creating': False,
#   'motown': False,
#   'sound': False,
#   'karmen': False,
#   'moves': False,
#   'rhythm': False,
#   'itself': False,
#   'lips': False,
#   'chanting': False,
#   'beat': False,
#   'long': False,
#   'braided': False,
#   'hair': False,
#   'little': False,
#   'wipe': False,
#   'away': False,
#   'jeweled': False,
#   'beads': False,
#   'sweat': False,
#   'gosling': False,
#   'performance': False,
#   'dwarfs': False,
#   'else': False,
#   'people': False,
#   'gives': False,
#   'glimpse': False,
#   'culture': False,
#   'do': False,
#   'know': False,
#   'tender': False,
#   'yet': False,
#   'lacerating': False,
#   'darkly': False,
#   'funny': False,
#   'fable': False,
#   'may': False,
#   'spoofing': False,
#   'target': False,
#   'old': False,
#   "'50": False,
#   'giant': False,
#   'creature': False,
#   'features': False,
#   'acknowledges': False,
#   'celebrates': False,
#   'their': False,
#   'cheesiness': False,
#   'reason': False,
#   'get': False,
#   'kick': False,
#   'watching': False,
#   'today': False,
#   'engaging': False,
#   'overview': False,
#   'johnson': False,
#   'eccentric': False,
#   'career': False,
#   'ragged': False,
#   'cheap': False,
#   'unassuming': False,
#   'works': False,
#   'charisma': False,
#   "'d": False,
#   'listen': False,
#   'reading': False,
#   'phone': False,
#   'book': False,
#   'sandra': False,
#   'bullock': False,
#   'such': False,
#   'likeable': False,
#   'nettelbeck': False,
#   'beautifully': False,
#   'orchestrates': False,
#   'transformation': False,
#   'chilly': False,
#   'self-absorbed': False,
#   'martha': False,
#   'begins': False,
#   'open': False,
#   'behind': False,
#   'snow': False,
#   'games': False,
#   'lovable': False,
#   'siberian': False,
#   'huskies': False,
#   'plus': False,
#   'sheep': False,
#   'dog': False,
#   'hosts': False,
#   'parka-wrapped': False,
#   'dose': False,
#   'everytime': False,
#   'undercover': False,
#   'brother': False,
#   'run': False,
#   'steam': False,
#   'finds': False,
#   'surprise': False,
#   'amuse': False,
#   'manages': False,
#   'original': False,
#   'rips': False,
#   'many': False,
#   'ideas': False,
#   'singer/composer': False,
#   'bryan': False,
#   'adams': False,
#   'contributes': False,
#   'slew': False,
#   'songs': False,
#   '—': False,
#   'potential': False,
#   'hits': False,
#   'simply': False,
#   'intrusive': False,
#   'whole': False,
#   'package': False,
#   'certainly': False,
#   'intended': False,
#   'er': False,
#   'spirit': False,
#   'piece': False,
#   'now': False,
#   'america': False,
#   'enough': False,
#   'plucky': False,
#   'british': False,
#   'eccentrics': False,
#   'hearts': False,
#   'gold': False,
#   'still': False,
#   'charming': False,
#   'here': False,
#   'whether': False,
#   "'re": False,
#   'enlightened': False,
#   'derrida': False,
#   'lectures': False,
#   'other': False,
#   'self': False,
#   'undeniably': False,
#   'playful': False,
#   'fellow': False,
#   'pleasant': False,
#   'held': False,
#   'together': False,
#   'skilled': False,
#   'ensemble': False,
#   'american': False,
#   'troubled': False,
#   'teens': False,
#   'since': False,
#   '1998': False,
#   'whatever': False,
#   'been': False,
#   'hit-or-miss': False,
#   'when': False,
#   'bringing': False,
#   'beloved': False,
#   'books': False,
#   'screen': False,
#   'tuck': False,
#   'everlasting': False,
#   'both': False,
#   'just': False,
#   'labour': False,
#   'involved': False,
#   'layered': False,
#   'richness': False,
#   'chiaroscuro': False,
#   'madness': False,
#   'astonishing': False,
#   'animated': False,
#   'subplot': False,
#   'depicts': False,
#   'inner': False,
#   'struggles': False,
#   'adolescent': False,
#   'heroes': False,
#   '-': False,
#   'insecure': False,
#   'uncontrolled': False,
#   'intense': False,
#   'invincible': False,
#   'werner': False,
#   'herzog': False,
#   'alive': False,
#   'living': False,
#   'morton': False,
#   'actress': False,
#   'portraying': False,
#   'complex': False,
#   'character': False,
#   'morvern': False,
#   'callar': False,
#   'grows': False,
#   'farther': False,
#   'meanders': False,
#   'shocking': False,
#   'part': False,
#   'charm': False,
#   'satin': False,
#   'rouge': False,
#   'avoids': False,
#   'obvious': False,
#   'humour': False,
#   'lightness': False,
#   'son': False,
#   'bride': False,
#   'half-hour': False,
#   'too': False,
#   'flattering': False,
#   'sense': False,
#   'mystery': False,
#   'quietness': False,
#   'simmering': False,
#   'psychological': False,
#   'drama': False,
#   'bursts': False,
#   'sudden': False,
#   'violence': False,
#   'startling': False,
#   'slow': False,
#   'buildup': False,
#   'preceded': False,
#   'taut': False,
#   'intelligent': False,
#   'coming-of-age': False,
#   'arduous': False,
#   'journey': False,
#   'sensitive': False,
#   'young': False,
#   'girl': False,
#   'foster': False,
#   'homes': False,
#   'fierce': False,
#   'struggle': False,
#   'pull': False,
#   'free': False,
#   'dangerous': False,
#   'domineering': False,
#   'mother': False,
#   'hold': False,
#   'over': False,
#   'truly': False,
#   'moving': False,
#   'experience': False,
#   'perfect': False,
#   'example': False,
#   'art': False,
#   'done': False,
#   'right': False,
#   'help': False,
#   'heal': False,
#   'clarify': False,
#   'comfort': False,
#   'delicately': False,
#   'deeply': False,
#   'felt': False,
#   'masterfully': False,
#   'stylized': False,
#   'triumph': False,
#   'maverick': False,
#   'director': False,
#   'deftly': False,
#   'wrought': False,
#   'suspense': False,
#   'whose': False,
#   'richer': False,
#   'shadings': False,
#   'coloring': False,
#   'rather': False,
#   'substance': False,
#   'appearance': False,
#   'treebeard': False,
#   'gollum': False,
#   'role': False,
#   'either': False,
#   'loving': False,
#   'rolling': False,
#   'your': False,
#   'eyes': False,
#   'loved': False,
#   '!': False,
#   "'performance": False,
#   'incredible': False,
#   'ingeniously': False,
#   'constructed': False,
#   'memento': False,
#   'were': False,
#   'page-turner': False,
#   'ca': False,
#   'wait': False,
#   'see': False,
#   'happens': False,
#   'next': False,
#   'haneke': False,
#   'challenges': False,
#   'confront': False,
#   'reality': False,
#   'sexual': False,
#   'aberration': False,
#   'absorbing': False,
#   'originally': False,
#   'clarity': False,
#   'gone': False,
#   'year': False,
#   'benchmark': False,
#   'against': False,
#   'contenders': False,
#   'should': False,
#   'measured': False,
#   'painful': False,
#   'watch': False,
#   'viewers': False,
#   'chance': False,
#   'rewarded': False,
#   'accomplished': False,
#   'riveting': False,
#   'performances': False,
#   'albeit': False,
#   'depressing': False,
#   'view': False,
#   'iranian': False,
#   'rural': False,
#   'life': False,
#   'close': False,
#   'iraqi': False,
#   'imaginative': False,
#   'comedy/thriller': False,
#   'artsy': False,
#   'flourishes': False,
#   'aside': False,
#   'narc': False,
#   'gritty': False,
#   'gets': False,
#   'these': False,
#   'isle': False,
#   'preposterous': False,
#   'thoroughly': False,
#   'misogynistic': False,
#   'vistas': False,
#   'incredibly': False,
#   'beautiful': False,
#   'look': False,
#   'tok': False,
#   'o': False,
#   'orchestrate': False,
#   'buoyant': False,
#   'dance': False,
#   'death': False,
#   'process': False,
#   'demonstrate': False,
#   'lot': False,
#   'hong': False,
#   'kong': False,
#   'kapur': False,
#   'flair': False,
#   'landscapes': False,
#   'adventure': False,
#   'english-language': False,
#   'overpraised': False,
#   'elizabeth': False,
#   'blast': False,
#   'educational': False,
#   'energy': False,
#   'bouncy': False,
#   'animation': False,
#   'catchy': False,
#   'escort': False,
#   'entire': False,
#   '85': False,
#   'sports': False,
#   'action': False,
#   'exciting': False,
#   'field': False,
#   'doug': False,
#   'liman': False,
#   'bourne': False,
#   'directs': False,
#   'traffic': False,
#   'wintry': False,
#   'locations': False,
#   'absorbs': False,
#   'spycraft': False,
#   'uses': False,
#   'damon': False,
#   'ability': False,
#   'focused': False,
#   'sincere': False,
#   'intact': False,
#   'katz': False,
#   'archival': False,
#   'footage': False,
#   'horrifying': False,
#   'documents': False,
#   'lynchings': False,
#   'photographs': False,
#   'reel-to-reel': False,
#   'recordings': False,
#   'meeropol': False,
#   'entertaining': False,
#   'children': False,
#   'create': False,
#   'song': False,
#   'history': False,
#   'powerful': False,
#   'anthropologically': False,
#   'detailed': False,
#   'realization': False,
#   "early-'80s": False,
#   'suburbia': False,
#   'significant': False,
#   'without': False,
#   'overstated': False,
#   'mcfarlane': False,
#   'lifts': False,
#   'firmly': False,
#   'above': False,
#   'level': False,
#   'films': False,
#   'jarring': False,
#   'hard': False,
#   'back': False,
#   'boys': False,
#   'nothing': False,
#   'introduces': False,
#   'promising': False,
#   'unusual': False,
#   'kind': False,
#   'horror': False,
#   'normal': False,
#   'bromides': False,
#   'barely': False,
#   'sustain': False,
#   'interstitial': False,
#   'program': False,
#   'discovery': False,
#   'channel': False,
#   'imax': False,
#   '3-d': False,
#   'clichés': False,
#   'disappear': False,
#   'vertiginous': False,
#   'perspectives': False,
#   'opened': False,
#   'up': False,
#   'photography': False,
#   'writer-director': False,
#   'burger': False,
#   'imaginatively': False,
#   'fans': False,
#   'embers': False,
#   'dormant': False,
#   'national': False,
#   'grief': False,
#   'curiosity': False,
#   'calcified': False,
#   'chronic': False,
#   'cynicism': False,
#   'fear': False,
#   'roller-coaster': False,
#   'enjoyed': False,
#   'time': False,
#   'favor': False,
#   'was': False,
#   'surprised': False,
#   'quickly': False,
#   'faded': False,
#   'memory': False,
#   'chicago': False,
#   'sophisticated': False,
#   'brash': False,
#   'sardonic': False,
#   'completely': False,
#   'joyful': False,
#   'execution': False,
#   'steve': False,
#   'irwin': False,
#   'method': False,
#   'ernest': False,
#   'hemmingway': False,
#   'accelerated': False,
#   'speed': False,
#   'volume': False,
#   'refreshing': False,
#   'korean': False,
#   'five': False,
#   'female': False,
#   'high': False,
#   'school': False,
#   'friends': False,
#   'face': False,
#   'uphill': False,
#   'battle': False,
#   'try': False,
#   'relationships': False,
#   'deeper': False,
#   'waters': False,
#   'surface': False,
#   'lovers-on-the-run': False,
#   'crime': False,
#   'flick': False,
#   'common': False,
#   'piesiewicz': False,
#   'kieslowski': False,
#   'double': False,
#   'veronique': False,
#   'values': False,
#   'enterprise': False,
#   'crew': False,
#   'previous': False,
#   'adventures': False,
#   'perils': False,
#   'again-courage': False,
#   'self-sacrifice': False,
#   'patience': False,
#   'under': False,
#   'pressure': False,
#   'possible': False,
#   'sequel': False,
#   ...},
#  'neg')
